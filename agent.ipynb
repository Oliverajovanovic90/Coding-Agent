# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import shutil

def start():
    project_name = input("Enter the new Django project name: ").strip()
    
    if not project_name:
        print("Project name cannot be empty.")
        return

    if os.path.exists(project_name):
        print(
            f"Directory '{project_name}' already exists. "
            "Please choose a different name or remove the existing directory."
        )
        return

    shutil.copytree('django_template', project_name)
    print(f"Django template copied to '{project_name}' directory.")

    return project_name

# %%
project_name = start()
# Out:
# Enter the new Django project name:  my_new_app
# Directory 'my_new_app' already exists. Please choose a different name or remove the existing directory.

# %%
print(project_name)
# Out:
# None

# %%
project_name = "my_new_app"

# %% [markdown]
# ### AI Test

# %%
from pathlib import Path
import tools

project_path = Path(project_name)
agent_tools = tools.AgentTools(project_path)

agent_tools.list_files()[:5]
# Out:
# ['.python-version',
#  '.venv/.gitignore',
#  '.venv/.lock',
#  '.venv/CACHEDIR.TAG',
#  '.venv/bin/activate']

# %%
import tools
from pathlib import Path

project_path = Path(project_name)  # project_name was created by start()
agent_tools = tools.AgentTools(project_path)

agent_tools
# Out:
# AgentTools(project_path=PosixPath('my_new_app'))

# %%
print(agent_tools.read_file("myproject/settings.py")[:200])
# Out:
# """
# Django settings for myproject project.
#
# Generated by 'django-admin startproject' using Django 6.0.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/6.0/topics/settings/
#
# F

# %%
agent_tools.write_file(
    "TEST_AGENT.txt",
    "Hello from the agent tools!"
)
# Out:
# 'Wrote 27 characters to TEST_AGENT.txt'

# %%
print(agent_tools.read_file("TEST_AGENT.txt"))
# Out:
# Hello from the agent tools!

# %%
files = agent_tools.list_files()
files[:10]
# Out:
# ['.python-version',
#  '.venv/.gitignore',
#  '.venv/.lock',
#  '.venv/CACHEDIR.TAG',
#  '.venv/bin/activate',
#  '.venv/bin/activate.bat',
#  '.venv/bin/activate.csh',
#  '.venv/bin/activate.fish',
#  '.venv/bin/activate.nu',
#  '.venv/bin/activate.ps1']

# %%
agent_tools.grep("INSTALLED_APPS")
# Out:
# ['myproject/settings.py:33: INSTALLED_APPS = [',
#  'myproject/__pycache__/settings.cpython-312.pyc:30: ALLOWED_HOSTS\x0eINSTALLED_APPS',
#  '.venv/lib/python3.12/site-packages/django/__init__.py:24: apps.populate(settings.INSTALLED_APPS)',
#  '.venv/lib/python3.12/site-packages/django/test/utils.py:486: # in case it raises an exception because INSTALLED_APPS is invalid.',
#  '.venv/lib/python3.12/site-packages/django/test/utils.py:487: if "INSTALLED_APPS" in self.options:',
#  '.venv/lib/python3.12/site-packages/django/test/utils.py:489: apps.set_installed_apps(self.options["INSTALLED_APPS"])',
#  '.venv/lib/python3.12/site-packages/django/test/utils.py:511: if "INSTALLED_APPS" in self.options:',
#  '.venv/lib/python3.12/site-packages/django/test/utils.py:608: Useful when you override `INSTALLED_APPS`, e.g. if you exclude `auth` app,',
#  '.venv/lib/python3.12/site-packages/django/test/testcases.py:1157: setting="INSTALLED_APPS",',
#  '.venv/lib/python3.12/site-packages/django/test/testcases.py:1170: setting="INSTALLED_APPS",',
#  '.venv/lib/python3.12/site-packages/django/test/testcases.py:1171: value=settings.INSTALLED_APPS,',
#  '.venv/lib/python3.12/site-packages/django/test/testcases.py:1257: setting="INSTALLED_APPS",',
#  '.venv/lib/python3.12/site-packages/django/test/testcases.py:1258: value=settings.INSTALLED_APPS,',
#  '.venv/lib/python3.12/site-packages/django/test/signals.py:38: if setting == "INSTALLED_APPS":',
#  '.venv/lib/python3.12/site-packages/django/test/signals.py:96: "INSTALLED_APPS",',
#  '.venv/lib/python3.12/site-packages/django/apps/registry.py:135: # INSTALLED_APPS raises a more helpful ImproperlyConfigured',
#  '.venv/lib/python3.12/site-packages/django/apps/registry.py:137: settings.INSTALLED_APPS',
#  '.venv/lib/python3.12/site-packages/django/apps/registry.py:343: installed must be an iterable in the same format as INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/apps/config.py:102: Factory that creates an app config from an entry in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/apps/config.py:175: # message for typos in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/apps/config.py:201: # all error checking for entries in INSTALLED_APPS in one place.',
#  '.venv/lib/python3.12/site-packages/django/conf/global_settings.py:215: INSTALLED_APPS = []',
#  '.venv/lib/python3.12/site-packages/django/conf/__init__.py:166: "INSTALLED_APPS",',
#  '.venv/lib/python3.12/site-packages/django/__pycache__/__init__.cpython-312.pyc:14: \x00\x00\x00\x0eLOGGING_CONFIG\x07LOGGING\x11FORCE_SCRIPT_NAME\x08populate\x0eINSTALLED_APPS)\x05',
#  '.venv/lib/python3.12/site-packages/django/utils/module_loading.py:40: Auto-discover INSTALLED_APPS modules and fail silently when',
#  '.venv/lib/python3.12/site-packages/django/views/templates/technical_500.html:310: {{ settings.INSTALLED_APPS|pprint }}',
#  '.venv/lib/python3.12/site-packages/django/views/templates/technical_500.txt:12: {{ settings.INSTALLED_APPS|pprint }}',
#  '.venv/lib/python3.12/site-packages/django/db/models/base.py:139: "INSTALLED_APPS." % (module, name)',
#  '.venv/lib/python3.12/site-packages/django/db/migrations/loader.py:75: """Load the migrations from all INSTALLED_APPS from disk."""',
#  ".venv/lib/python3.12/site-packages/django/db/models/__pycache__/base.cpython-312.pyc:145: Model class rH\x00\x00\x00zU doesn't declare an explicit app_label and isn't in an application in INSTALLED_APPS.",
#  ".venv/lib/python3.12/site-packages/django/db/migrations/__pycache__/loader.cpython-312.pyc:99: z6Load the migrations from all INSTALLED_APPS from disk.N\x08__path__\x08__file__r \x00\x00\x00r\x02\x00\x00\x00z\x02_~z\x10bad magic numberz9Couldn't import %r as it appears to be a stale .pyc file.\tMigrationz",
#  '.venv/lib/python3.12/site-packages/django/db/backends/base/creation.py:362: if test_app in settings.INSTALLED_APPS:',
#  '.venv/lib/python3.12/site-packages/django/db/backends/base/creation.py:372: if test_app in settings.INSTALLED_APPS:',
#  '.venv/lib/python3.12/site-packages/django/db/backends/base/introspection.py:97: are in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/db/backends/base/__pycache__/introspection.cpython-312.pyc:86: are in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/db/backends/base/__pycache__/creation.cpython-312.pyc:351: rpartition\x05splitr\x05\x00\x00\x00\x0eINSTALLED_APPSr',
#  '.venv/lib/python3.12/site-packages/django/apps/__pycache__/config.cpython-312.pyc:101: Factory that creates an app config from an entry in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/apps/__pycache__/registry.cpython-312.pyc:136: django.confr@\x00\x00\x00\x0eINSTALLED_APPSr\x06\x00\x00\x00)\x02r#\x00\x00\x00r@\x00\x00\x00s\x02\x00\x00\x00  r%\x00\x00\x00\x10check_apps_readyz\x15Apps.check_apps_ready\x00\x00\x00s(\x00\x00\x00\x00\x0f\x13\x7f\x7f',
#  '.venv/lib/python3.12/site-packages/django/apps/__pycache__/registry.cpython-312.pyc:344: installed must be an iterable in the same format as INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/template/loaders/app_directories.py:2: Wrapper for loading templates from "templates" directories in INSTALLED_APPS',
#  '.venv/lib/python3.12/site-packages/django/conf/__pycache__/global_settings.cpython-312.pyc:60: EMAIL_TIMEOUT\x0eINSTALLED_APPS\tTEMPLATES',
#  '.venv/lib/python3.12/site-packages/django/conf/__pycache__/__init__.cpython-312.pyc:173: ALLOWED_HOSTS\x0eINSTALLED_APPS',
#  '.venv/lib/python3.12/site-packages/django/conf/project_template/project_name/settings.py-tpl:33: INSTALLED_APPS = [',
#  '.venv/lib/python3.12/site-packages/django/core/management/base.py:648: "%s. Are you sure your INSTALLED_APPS setting is correct?" % e',
#  '.venv/lib/python3.12/site-packages/django/core/management/__init__.py:263: settings.INSTALLED_APPS',
#  '.venv/lib/python3.12/site-packages/django/core/management/__init__.py:383: settings.INSTALLED_APPS',
#  '.venv/lib/python3.12/site-packages/django/core/management/__pycache__/__init__.cpython-312.pyc:311: \x00\x00\x00\x0eINSTALLED_APPSr,\x00\x00\x00r\x00\x00\x00\x06stderr\x05writer\x08\x00\x00\x00r\x00\x00\x00\x04exitr;\x00\x00\x00r',
#  '.venv/lib/python3.12/site-packages/django/core/management/__pycache__/base.cpython-312.pyc:736: \x00\x00\x00\x00\x00\x00\x00\x00d\x03|\x06z\x06\x00\x00\x01\x00\x00\x00\x00\x00\x00\x01d\x00}\x06~\x06w\x01w\x00x\x03Y\x00w\x01)\x05Nr\x02\x00\x00\x00)\x01\x04appsz8%s. Are you sure your INSTALLED_APPS setting is correct?r\x00\x00\x00)',
#  '.venv/lib/python3.12/site-packages/django/core/management/commands/shell.py:127: By default, import paths for models in INSTALLED_APPS and some common',
#  '.venv/lib/python3.12/site-packages/django/core/management/commands/shell.py:131: For example, for an unchanged INSTALLED_APPS, this method returns:',
#  '.venv/lib/python3.12/site-packages/django/core/management/commands/sqlmigrate.py:67: "INSTALLED_APPS?" % (migration_name, app_label)',
#  '.venv/lib/python3.12/site-packages/django/core/checks/security/sessions.py:15: "You have \'django.contrib.sessions\' in your INSTALLED_APPS, "',
#  '.venv/lib/python3.12/site-packages/django/core/checks/security/sessions.py:45: "You have \'django.contrib.sessions\' in your INSTALLED_APPS, "',
#  '.venv/lib/python3.12/site-packages/django/core/checks/security/sessions.py:99: return "django.contrib.sessions" in settings.INSTALLED_APPS',
#  ".venv/lib/python3.12/site-packages/django/core/checks/security/__pycache__/sessions.cpython-312.pyc:20: \x06\x00\x03\x05\x06\x00\x00\x00\x00znYou have 'django.contrib.sessions' in your INSTALLED_APPS, but you have not set SESSION_COOKIE_SECURE to True.z",
#  ".venv/lib/python3.12/site-packages/django/core/checks/security/__pycache__/sessions.cpython-312.pyc:28: \x06\x00\x03\x05\x06r\x0e\x00\x00\x00zpYou have 'django.contrib.sessions' in your INSTALLED_APPS, but you have not set SESSION_COOKIE_HTTPONLY to True.z",
#  '.venv/lib/python3.12/site-packages/django/core/checks/security/__pycache__/sessions.cpython-312.pyc:64: X\x04Xr\x0e\x00\x00\x00c\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x03\x00\x00\x00&\x00\x00\x00\x00d\x01t\x00\x00\x00\x00\x00\x00\x00\x00\x00j\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00v\x00S\x00)\x02Nz\x17django.contrib.sessions)\x02r\x03\x00\x00\x00\x0eINSTALLED_APPSr\t\x00\x00\x00r\x0e\x00\x00\x00r',
#  '.venv/lib/python3.12/site-packages/django/utils/__pycache__/module_loading.cpython-312.pyc:45: Auto-discover INSTALLED_APPS modules and fail silently when',
#  '.venv/lib/python3.12/site-packages/django/contrib/postgres/utils.py:42: "\'django.contrib.postgres\' must be in INSTALLED_APPS in "',
#  '.venv/lib/python3.12/site-packages/django/contrib/postgres/apps.py:31: and setting == "INSTALLED_APPS"',
#  '.venv/lib/python3.12/site-packages/django/contrib/auth/base_user.py:3: not in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/contrib/sessions/base_session.py:3: when django.contrib.sessions is not in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/checks.py:74: "\'%s\' must be in INSTALLED_APPS in order to use the admin "',
#  '.venv/lib/python3.12/site-packages/django/contrib/contenttypes/management/commands/remove_stale_contenttypes.py:33: "installed apps that have been removed from INSTALLED_APPS."',
#  ".venv/lib/python3.12/site-packages/django/contrib/auth/management/__init__.py:59: # 'django.contrib.auth' is in INSTALLED_APPS before",
#  '.venv/lib/python3.12/site-packages/django/contrib/auth/__pycache__/base_user.cpython-312.pyc:18: not in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/contrib/sessions/__pycache__/base_session.cpython-312.pyc:6: when django.contrib.sessions is not in INSTALLED_APPS.',
#  '.venv/lib/python3.12/site-packages/django/contrib/sessions/backends/db.py:23: # django.contrib.sessions is not in INSTALLED_APPS.',
#  ".venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/checks.cpython-312.pyc:94: r\x02\x00\x00\x00r$\x00\x00\x00z\x14django.contrib.admin)\x03)\x02z\x1bdjango.contrib.contenttypesi\x01\x00\x00)\x02z\x13django.contrib.authi\x01\x00\x00)\x02z\x17django.contrib.messagesi\x01\x00\x00zE'%s' must be in INSTALLED_APPS in order to use the admin application.z\tadmin.E%d)\x01\x02idNzA 'django.template.backends.django.DjangoTemplates' instance must be configured in TEMPLATES in order to use the admin application.z",
#  '.venv/lib64/python3.12/site-packages/django/__init__.py:24: apps.populate(settings.INSTALLED_APPS)',
#  '.venv/lib64/python3.12/site-packages/django/test/utils.py:486: # in case it raises an exception because INSTALLED_APPS is invalid.',
#  '.venv/lib64/python3.12/site-packages/django/test/utils.py:487: if "INSTALLED_APPS" in self.options:',
#  '.venv/lib64/python3.12/site-packages/django/test/utils.py:489: apps.set_installed_apps(self.options["INSTALLED_APPS"])',
#  '.venv/lib64/python3.12/site-packages/django/test/utils.py:511: if "INSTALLED_APPS" in self.options:',
#  '.venv/lib64/python3.12/site-packages/django/test/utils.py:608: Useful when you override `INSTALLED_APPS`, e.g. if you exclude `auth` app,',
#  '.venv/lib64/python3.12/site-packages/django/test/testcases.py:1157: setting="INSTALLED_APPS",',
#  '.venv/lib64/python3.12/site-packages/django/test/testcases.py:1170: setting="INSTALLED_APPS",',
#  '.venv/lib64/python3.12/site-packages/django/test/testcases.py:1171: value=settings.INSTALLED_APPS,',
#  '.venv/lib64/python3.12/site-packages/django/test/testcases.py:1257: setting="INSTALLED_APPS",',
#  '.venv/lib64/python3.12/site-packages/django/test/testcases.py:1258: value=settings.INSTALLED_APPS,',
#  '.venv/lib64/python3.12/site-packages/django/test/signals.py:38: if setting == "INSTALLED_APPS":',
#  '.venv/lib64/python3.12/site-packages/django/test/signals.py:96: "INSTALLED_APPS",',
#  '.venv/lib64/python3.12/site-packages/django/apps/registry.py:135: # INSTALLED_APPS raises a more helpful ImproperlyConfigured',
#  '.venv/lib64/python3.12/site-packages/django/apps/registry.py:137: settings.INSTALLED_APPS',
#  '.venv/lib64/python3.12/site-packages/django/apps/registry.py:343: installed must be an iterable in the same format as INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/apps/config.py:102: Factory that creates an app config from an entry in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/apps/config.py:175: # message for typos in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/apps/config.py:201: # all error checking for entries in INSTALLED_APPS in one place.',
#  '.venv/lib64/python3.12/site-packages/django/conf/global_settings.py:215: INSTALLED_APPS = []',
#  '.venv/lib64/python3.12/site-packages/django/conf/__init__.py:166: "INSTALLED_APPS",',
#  '.venv/lib64/python3.12/site-packages/django/__pycache__/__init__.cpython-312.pyc:14: \x00\x00\x00\x0eLOGGING_CONFIG\x07LOGGING\x11FORCE_SCRIPT_NAME\x08populate\x0eINSTALLED_APPS)\x05',
#  '.venv/lib64/python3.12/site-packages/django/utils/module_loading.py:40: Auto-discover INSTALLED_APPS modules and fail silently when',
#  '.venv/lib64/python3.12/site-packages/django/views/templates/technical_500.html:310: {{ settings.INSTALLED_APPS|pprint }}',
#  '.venv/lib64/python3.12/site-packages/django/views/templates/technical_500.txt:12: {{ settings.INSTALLED_APPS|pprint }}',
#  '.venv/lib64/python3.12/site-packages/django/db/models/base.py:139: "INSTALLED_APPS." % (module, name)',
#  '.venv/lib64/python3.12/site-packages/django/db/migrations/loader.py:75: """Load the migrations from all INSTALLED_APPS from disk."""',
#  ".venv/lib64/python3.12/site-packages/django/db/models/__pycache__/base.cpython-312.pyc:145: Model class rH\x00\x00\x00zU doesn't declare an explicit app_label and isn't in an application in INSTALLED_APPS.",
#  ".venv/lib64/python3.12/site-packages/django/db/migrations/__pycache__/loader.cpython-312.pyc:99: z6Load the migrations from all INSTALLED_APPS from disk.N\x08__path__\x08__file__r \x00\x00\x00r\x02\x00\x00\x00z\x02_~z\x10bad magic numberz9Couldn't import %r as it appears to be a stale .pyc file.\tMigrationz",
#  '.venv/lib64/python3.12/site-packages/django/db/backends/base/creation.py:362: if test_app in settings.INSTALLED_APPS:',
#  '.venv/lib64/python3.12/site-packages/django/db/backends/base/creation.py:372: if test_app in settings.INSTALLED_APPS:',
#  '.venv/lib64/python3.12/site-packages/django/db/backends/base/introspection.py:97: are in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/db/backends/base/__pycache__/introspection.cpython-312.pyc:86: are in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/db/backends/base/__pycache__/creation.cpython-312.pyc:351: rpartition\x05splitr\x05\x00\x00\x00\x0eINSTALLED_APPSr',
#  '.venv/lib64/python3.12/site-packages/django/apps/__pycache__/config.cpython-312.pyc:101: Factory that creates an app config from an entry in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/apps/__pycache__/registry.cpython-312.pyc:136: django.confr@\x00\x00\x00\x0eINSTALLED_APPSr\x06\x00\x00\x00)\x02r#\x00\x00\x00r@\x00\x00\x00s\x02\x00\x00\x00  r%\x00\x00\x00\x10check_apps_readyz\x15Apps.check_apps_ready\x00\x00\x00s(\x00\x00\x00\x00\x0f\x13\x7f\x7f',
#  '.venv/lib64/python3.12/site-packages/django/apps/__pycache__/registry.cpython-312.pyc:344: installed must be an iterable in the same format as INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/template/loaders/app_directories.py:2: Wrapper for loading templates from "templates" directories in INSTALLED_APPS',
#  '.venv/lib64/python3.12/site-packages/django/conf/__pycache__/global_settings.cpython-312.pyc:60: EMAIL_TIMEOUT\x0eINSTALLED_APPS\tTEMPLATES',
#  '.venv/lib64/python3.12/site-packages/django/conf/__pycache__/__init__.cpython-312.pyc:173: ALLOWED_HOSTS\x0eINSTALLED_APPS',
#  '.venv/lib64/python3.12/site-packages/django/conf/project_template/project_name/settings.py-tpl:33: INSTALLED_APPS = [',
#  '.venv/lib64/python3.12/site-packages/django/core/management/base.py:648: "%s. Are you sure your INSTALLED_APPS setting is correct?" % e',
#  '.venv/lib64/python3.12/site-packages/django/core/management/__init__.py:263: settings.INSTALLED_APPS',
#  '.venv/lib64/python3.12/site-packages/django/core/management/__init__.py:383: settings.INSTALLED_APPS',
#  '.venv/lib64/python3.12/site-packages/django/core/management/__pycache__/__init__.cpython-312.pyc:311: \x00\x00\x00\x0eINSTALLED_APPSr,\x00\x00\x00r\x00\x00\x00\x06stderr\x05writer\x08\x00\x00\x00r\x00\x00\x00\x04exitr;\x00\x00\x00r',
#  '.venv/lib64/python3.12/site-packages/django/core/management/__pycache__/base.cpython-312.pyc:736: \x00\x00\x00\x00\x00\x00\x00\x00d\x03|\x06z\x06\x00\x00\x01\x00\x00\x00\x00\x00\x00\x01d\x00}\x06~\x06w\x01w\x00x\x03Y\x00w\x01)\x05Nr\x02\x00\x00\x00)\x01\x04appsz8%s. Are you sure your INSTALLED_APPS setting is correct?r\x00\x00\x00)',
#  '.venv/lib64/python3.12/site-packages/django/core/management/commands/shell.py:127: By default, import paths for models in INSTALLED_APPS and some common',
#  '.venv/lib64/python3.12/site-packages/django/core/management/commands/shell.py:131: For example, for an unchanged INSTALLED_APPS, this method returns:',
#  '.venv/lib64/python3.12/site-packages/django/core/management/commands/sqlmigrate.py:67: "INSTALLED_APPS?" % (migration_name, app_label)',
#  '.venv/lib64/python3.12/site-packages/django/core/checks/security/sessions.py:15: "You have \'django.contrib.sessions\' in your INSTALLED_APPS, "',
#  '.venv/lib64/python3.12/site-packages/django/core/checks/security/sessions.py:45: "You have \'django.contrib.sessions\' in your INSTALLED_APPS, "',
#  '.venv/lib64/python3.12/site-packages/django/core/checks/security/sessions.py:99: return "django.contrib.sessions" in settings.INSTALLED_APPS',
#  ".venv/lib64/python3.12/site-packages/django/core/checks/security/__pycache__/sessions.cpython-312.pyc:20: \x06\x00\x03\x05\x06\x00\x00\x00\x00znYou have 'django.contrib.sessions' in your INSTALLED_APPS, but you have not set SESSION_COOKIE_SECURE to True.z",
#  ".venv/lib64/python3.12/site-packages/django/core/checks/security/__pycache__/sessions.cpython-312.pyc:28: \x06\x00\x03\x05\x06r\x0e\x00\x00\x00zpYou have 'django.contrib.sessions' in your INSTALLED_APPS, but you have not set SESSION_COOKIE_HTTPONLY to True.z",
#  '.venv/lib64/python3.12/site-packages/django/core/checks/security/__pycache__/sessions.cpython-312.pyc:64: X\x04Xr\x0e\x00\x00\x00c\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x03\x00\x00\x00&\x00\x00\x00\x00d\x01t\x00\x00\x00\x00\x00\x00\x00\x00\x00j\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00v\x00S\x00)\x02Nz\x17django.contrib.sessions)\x02r\x03\x00\x00\x00\x0eINSTALLED_APPSr\t\x00\x00\x00r\x0e\x00\x00\x00r',
#  '.venv/lib64/python3.12/site-packages/django/utils/__pycache__/module_loading.cpython-312.pyc:45: Auto-discover INSTALLED_APPS modules and fail silently when',
#  '.venv/lib64/python3.12/site-packages/django/contrib/postgres/utils.py:42: "\'django.contrib.postgres\' must be in INSTALLED_APPS in "',
#  '.venv/lib64/python3.12/site-packages/django/contrib/postgres/apps.py:31: and setting == "INSTALLED_APPS"',
#  '.venv/lib64/python3.12/site-packages/django/contrib/auth/base_user.py:3: not in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/contrib/sessions/base_session.py:3: when django.contrib.sessions is not in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/contrib/admin/checks.py:74: "\'%s\' must be in INSTALLED_APPS in order to use the admin "',
#  '.venv/lib64/python3.12/site-packages/django/contrib/contenttypes/management/commands/remove_stale_contenttypes.py:33: "installed apps that have been removed from INSTALLED_APPS."',
#  ".venv/lib64/python3.12/site-packages/django/contrib/auth/management/__init__.py:59: # 'django.contrib.auth' is in INSTALLED_APPS before",
#  '.venv/lib64/python3.12/site-packages/django/contrib/auth/__pycache__/base_user.cpython-312.pyc:18: not in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/contrib/sessions/__pycache__/base_session.cpython-312.pyc:6: when django.contrib.sessions is not in INSTALLED_APPS.',
#  '.venv/lib64/python3.12/site-packages/django/contrib/sessions/backends/db.py:23: # django.contrib.sessions is not in INSTALLED_APPS.',
#  ".venv/lib64/python3.12/site-packages/django/contrib/admin/__pycache__/checks.cpython-312.pyc:94: r\x02\x00\x00\x00r$\x00\x00\x00z\x14django.contrib.admin)\x03)\x02z\x1bdjango.contrib.contenttypesi\x01\x00\x00)\x02z\x13django.contrib.authi\x01\x00\x00)\x02z\x17django.contrib.messagesi\x01\x00\x00zE'%s' must be in INSTALLED_APPS in order to use the admin application.z\tadmin.E%d)\x01\x02idNzA 'django.template.backends.django.DjangoTemplates' instance must be configured in TEMPLATES in order to use the admin application.z"]

# %%
agent_tools.run_bash("ls")
# Out:
# 'README.md\nTEST_AGENT.txt\nmanage.py\nmyapp\nmyproject\npyproject.toml\ntemplates\nuv.lock\n'

# %%
agent_tools.run_bash("python manage.py runserver")
# Out:
# 'Blocked: runserver commands are not allowed from the agent.'

# %% [markdown]
# ### Connect Agent to the LLM

# %%
from openai import OpenAI

from toyaikit.tools import Tools
from toyaikit.chat import IPythonChatInterface
from toyaikit.llm import OpenAIClient
from toyaikit.chat.runners import OpenAIResponsesRunner

# %% [markdown]
# #### Create the tools registry

# %%
tools_obj = Tools()
tools_obj.add_tools(agent_tools)

tools_obj

# %%
DEVELOPER_PROMPT = """
You are a coding agent.
For now, you can only READ files and explain them.
Do not modify any files yet.
"""

# %% [markdown]
# #### Create the runner (this connects everything)

# %%
chat_interface = IPythonChatInterface()
llm_client = OpenAIClient(client=OpenAI())

runner = OpenAIResponsesRunner(
    tools=tools_obj,
    developer_prompt=DEVELOPER_PROMPT,
    chat_interface=chat_interface,
    llm_client=llm_client,
)

# %% [markdown]
# ##### Test the agent

# %%
from openai import OpenAI
from toyaikit.tools import Tools
from toyaikit.llm import OpenAIClient
from toyaikit.chat.runners import OpenAIResponsesRunner

# %%
tools_obj = Tools()
tools_obj.add_tools(agent_tools)

DEVELOPER_PROMPT = """
You are a coding agent.
For now, you can only READ files and explain them.
Do not modify any files yet.
"""

runner = OpenAIResponsesRunner(
    tools=tools_obj,
    developer_prompt=DEVELOPER_PROMPT,
    llm_client=OpenAIClient(client=OpenAI()),
    chat_interface=None,   # 🔴 IMPORTANT: disable interactive mode
)

# %%
class OneShotChatInterface:
    def input(self):
        return "stop"  # immediately end the loop

    def display(self, message):
        print(message)

# %%
from openai import OpenAI
from toyaikit.tools import Tools
from toyaikit.llm import OpenAIClient
from toyaikit.chat.runners import OpenAIResponsesRunner

tools_obj = Tools()
tools_obj.add_tools(agent_tools)

DEVELOPER_PROMPT = """
You are a coding agent.
For now, you can only READ files and explain them.
Do not modify any files yet.
"""

runner = OpenAIResponsesRunner(
    tools=tools_obj,
    developer_prompt=DEVELOPER_PROMPT,
    chat_interface=OneShotChatInterface(),  # ✅ SAFE FIX
    llm_client=OpenAIClient(client=OpenAI()),
)

# %%
runner.run(
    "Read myproject/settings.py and summarize what this Django project is using."
)
# Out:
# Chat ended.
# LoopResult(new_messages=['R', 'e', 'a', 'd', ' ', 'm', 'y', 'p', 'r', 'o', 'j', 'e', 'c', 't', '/', 's', 'e', 't', 't', 'i', 'n', 'g', 's', '.', 'p', 'y', ' ', 'a', 'n', 'd', ' ', 's', 'u', 'm', 'm', 'a', 'r', 'i', 'z', 'e', ' ', 'w', 'h', 'a', 't', ' ', 't', 'h', 'i', 's', ' ', 'D', 'j', 'a', 'n', 'g', 'o', ' ', 'p', 'r', 'o', 'j', 'e', 'c', 't', ' ', 'i', 's', ' ', 'u', 's', 'i', 'n', 'g', '.'], all_messages=['R', 'e', 'a', 'd', ' ', 'm', 'y', 'p', 'r', 'o', 'j', 'e', 'c', 't', '/', 's', 'e', 't', 't', 'i', 'n', 'g', 's', '.', 'p', 'y', ' ', 'a', 'n', 'd', ' ', 's', 'u', 'm', 'm', 'a', 'r', 'i', 'z', 'e', ' ', 'w', 'h', 'a', 't', ' ', 't', 'h', 'i', 's', ' ', 'D', 'j', 'a', 'n', 'g', 'o', ' ', 'p', 'r', 'o', 'j', 'e', 'c', 't', ' ', 'i', 's', ' ', 'u', 's', 'i', 'n', 'g', '.'], tokens=TokenUsage(model='gpt-4o-mini', input_tokens=0, output_tokens=0), cost=CostInfo(input_cost=Decimal('0.000'), output_cost=Decimal('0.0'), total_cost=Decimal('0.000')), last_message='')

# %%
DEVELOPER_PROMPT = """
You are a coding agent.

You are allowed to:
- Read files
- Modify ONLY the file README.md

You are NOT allowed to modify any other files.

Task behavior:
- If asked to change something, first read README.md
- Then write an improved version back to README.md
- Keep changes simple and safe

If the request is outside README.md, refuse politely.
"""

# %%
runner = OpenAIResponsesRunner(
    tools=tools_obj,
    developer_prompt=DEVELOPER_PROMPT,
    chat_interface=OneShotChatInterface(),  # safe, non-interactive
    llm_client=OpenAIClient(client=OpenAI()),
)

# %%
agent_tools.list_files()
# Out:
# ['.python-version',
#  '.venv/.gitignore',
#  '.venv/.lock',
#  '.venv/CACHEDIR.TAG',
#  '.venv/bin/activate',
#  '.venv/bin/activate.bat',
#  '.venv/bin/activate.csh',
#  '.venv/bin/activate.fish',
#  '.venv/bin/activate.nu',
#  '.venv/bin/activate.ps1',
#  '.venv/bin/activate_this.py',
#  '.venv/bin/deactivate.bat',
#  '.venv/bin/django-admin',
#  '.venv/bin/pydoc.bat',
#  '.venv/bin/python',
#  '.venv/bin/python3',
#  '.venv/bin/python3.12',
#  '.venv/bin/sqlformat',
#  '.venv/lib/python3.12/site-packages/__pycache__/_virtualenv.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/_virtualenv.pth',
#  '.venv/lib/python3.12/site-packages/_virtualenv.py',
#  '.venv/lib/python3.12/site-packages/asgiref-3.11.0.dist-info/INSTALLER',
#  '.venv/lib/python3.12/site-packages/asgiref-3.11.0.dist-info/METADATA',
#  '.venv/lib/python3.12/site-packages/asgiref-3.11.0.dist-info/RECORD',
#  '.venv/lib/python3.12/site-packages/asgiref-3.11.0.dist-info/REQUESTED',
#  '.venv/lib/python3.12/site-packages/asgiref-3.11.0.dist-info/WHEEL',
#  '.venv/lib/python3.12/site-packages/asgiref-3.11.0.dist-info/licenses/LICENSE',
#  '.venv/lib/python3.12/site-packages/asgiref-3.11.0.dist-info/top_level.txt',
#  '.venv/lib/python3.12/site-packages/asgiref/__init__.py',
#  '.venv/lib/python3.12/site-packages/asgiref/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/asgiref/__pycache__/current_thread_executor.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/asgiref/__pycache__/local.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/asgiref/__pycache__/sync.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/asgiref/compatibility.py',
#  '.venv/lib/python3.12/site-packages/asgiref/current_thread_executor.py',
#  '.venv/lib/python3.12/site-packages/asgiref/local.py',
#  '.venv/lib/python3.12/site-packages/asgiref/py.typed',
#  '.venv/lib/python3.12/site-packages/asgiref/server.py',
#  '.venv/lib/python3.12/site-packages/asgiref/sync.py',
#  '.venv/lib/python3.12/site-packages/asgiref/testing.py',
#  '.venv/lib/python3.12/site-packages/asgiref/timeout.py',
#  '.venv/lib/python3.12/site-packages/asgiref/typing.py',
#  '.venv/lib/python3.12/site-packages/asgiref/wsgi.py',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/INSTALLER',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/METADATA',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/RECORD',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/REQUESTED',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/WHEEL',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/entry_points.txt',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/licenses/LICENSE',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/licenses/LICENSE.python',
#  '.venv/lib/python3.12/site-packages/django-6.0.dist-info/top_level.txt',
#  '.venv/lib/python3.12/site-packages/django/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/__main__.py',
#  '.venv/lib/python3.12/site-packages/django/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/__pycache__/shortcuts.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/apps/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/apps/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/apps/__pycache__/config.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/apps/__pycache__/registry.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/apps/config.py',
#  '.venv/lib/python3.12/site-packages/django/apps/registry.py',
#  '.venv/lib/python3.12/site-packages/django/conf/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/conf/__pycache__/global_settings.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/conf/app_template/__init__.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/app_template/admin.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/app_template/apps.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/app_template/migrations/__init__.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/app_template/models.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/app_template/tests.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/app_template/views.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/global_settings.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/af/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/af/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar_DZ/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar_DZ/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar_DZ/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ar_DZ/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ast/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ast/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/az/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/az/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/az/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/az/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/be/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/be/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bg/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bg/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bg/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bg/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bn/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bn/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bn/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bn/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/br/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/br/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bs/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bs/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bs/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/bs/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ca/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ca/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ca/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ca/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ckb/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ckb/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ckb/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ckb/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cs/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cs/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cs/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cs/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cy/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cy/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cy/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/cy/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/da/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/da/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/da/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/da/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/de/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/de/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/de/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/de/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/de_CH/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/de_CH/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/dsb/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/dsb/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/el/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/el/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/el/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/el/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_AU/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_AU/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_AU/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_AU/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_CA/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_CA/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_GB/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_GB/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_GB/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_GB/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_IE/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/en_IE/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eo/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eo/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eo/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eo/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_AR/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_AR/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_AR/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_AR/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_CO/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_CO/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_CO/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_CO/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_MX/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_MX/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_MX/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_MX/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_NI/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_NI/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_PR/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_PR/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_VE/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/es_VE/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/et/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/et/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/et/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/et/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eu/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eu/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eu/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/eu/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fa/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fa/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fa/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fa/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fi/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fi/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fi/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fi/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr_BE/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr_BE/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr_CA/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr_CA/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr_CH/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fr_CH/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fy/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fy/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fy/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/fy/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ga/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ga/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ga/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ga/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gd/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gd/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gd/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gd/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gl/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gl/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gl/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/gl/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/he/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/he/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/he/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/he/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hi/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hi/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hi/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hi/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hr/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hr/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hr/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hr/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hsb/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hsb/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ht/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ht/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hu/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hu/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hu/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hu/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hy/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/hy/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ia/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ia/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/id/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/id/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/id/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/id/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ig/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ig/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ig/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ig/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/io/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/io/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/is/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/is/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/is/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/is/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/it/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/it/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/it/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/it/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ja/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ja/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ja/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ja/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ka/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ka/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ka/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ka/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kab/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kab/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kk/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kk/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/km/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/km/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/km/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/km/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kn/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kn/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kn/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/kn/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ko/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ko/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ko/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ko/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ky/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ky/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ky/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ky/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lb/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lb/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lt/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lt/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lt/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lt/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lv/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lv/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lv/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/lv/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mk/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mk/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mk/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mk/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ml/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ml/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ml/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ml/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mn/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mn/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mn/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mn/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mr/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/mr/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ms/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ms/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ms/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ms/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/my/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/my/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nb/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nb/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nb/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nb/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ne/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ne/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nl/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nl/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nl/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nl/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nn/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nn/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nn/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/nn/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/os/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/os/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pa/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pa/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pl/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pl/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pl/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pl/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt_BR/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt_BR/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt_BR/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/pt_BR/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ro/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ro/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ro/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ro/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ru/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ru/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ru/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ru/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sk/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sk/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sk/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sk/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sl/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sl/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sl/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sl/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sq/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sq/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sq/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sq/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr_Latn/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr_Latn/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr_Latn/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sr_Latn/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sv/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sv/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sv/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sv/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sw/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/sw/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ta/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ta/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ta/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ta/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/te/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/te/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/te/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/te/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tg/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tg/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tg/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tg/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/th/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/th/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/th/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/th/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tk/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tk/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tk/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tk/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tr/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tr/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tr/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tr/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tt/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/tt/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/udm/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/udm/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ug/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ug/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ug/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ug/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uk/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uk/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uk/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uk/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ur/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/ur/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uz/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uz/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uz/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/uz/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/vi/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/vi/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/vi/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/vi/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hans/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hans/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hans/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hans/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hant/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hant/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hant/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/locale/zh_Hant/formats.py',
#  '.venv/lib/python3.12/site-packages/django/conf/project_template/manage.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/project_template/project_name/__init__.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/project_template/project_name/asgi.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/project_template/project_name/settings.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/project_template/project_name/urls.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/project_template/project_name/wsgi.py-tpl',
#  '.venv/lib/python3.12/site-packages/django/conf/urls/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/conf/urls/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/conf/urls/i18n.py',
#  '.venv/lib/python3.12/site-packages/django/conf/urls/static.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/__init__.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/actions.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/apps.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/checks.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/decorators.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/exceptions.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/filters.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/helpers.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/models.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/options.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/sites.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/utils.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/__pycache__/widgets.cpython-312.pyc',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/actions.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/apps.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/checks.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/decorators.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/exceptions.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/filters.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/forms.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/helpers.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/af/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/af/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/af/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/af/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/am/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/am/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar_DZ/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar_DZ/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar_DZ/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ar_DZ/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ast/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ast/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ast/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ast/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/az/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/az/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/az/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/az/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/be/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/be/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/be/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/be/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bg/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bg/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bg/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bg/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bn/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bn/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bn/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bn/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/br/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/br/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/br/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/br/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bs/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bs/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bs/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/bs/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ca/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ca/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ca/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ca/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ckb/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ckb/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ckb/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ckb/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cs/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cs/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cs/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cs/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cy/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cy/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cy/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/cy/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/da/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/da/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/da/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/da/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/de/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/de/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/de/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/de/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/dsb/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/dsb/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/dsb/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/dsb/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/el/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/el/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/el/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/el/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_AU/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_AU/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_AU/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_AU/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_GB/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_GB/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_GB/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/en_GB/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eo/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eo/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eo/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eo/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_AR/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_AR/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_AR/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_AR/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_CO/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_CO/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_CO/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_CO/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_MX/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_MX/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_MX/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_MX/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_VE/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_VE/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_VE/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/es_VE/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/et/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/et/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/et/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/et/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eu/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eu/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eu/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/eu/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/fa/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/fa/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/fa/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/fa/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/fi/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/fi/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/fi/LC_MESSAGES/djangojs.mo',
# ...
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ug/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ug/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ug/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ug/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uk/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uk/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uk/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uk/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ur/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ur/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ur/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/ur/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uz/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uz/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uz/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/uz/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/vi/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/vi/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/vi/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/vi/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hans/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hans/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hans/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hans/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hant/LC_MESSAGES/django.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hant/LC_MESSAGES/django.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hant/LC_MESSAGES/djangojs.mo',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/locale/zh_Hant/LC_MESSAGES/djangojs.po',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/migrations/0001_initial.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/migrations/0002_logentry_remove_auto_add.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/migrations/0003_logentry_add_action_flag_choices.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/migrations/__init__.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/models.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/options.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/sites.py',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/autocomplete.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/base.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/changelists.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/dark_mode.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/dashboard.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/forms.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/login.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/nav_sidebar.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/responsive.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/responsive_rtl.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/rtl.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/unusable_password_field.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/vendor/select2/LICENSE-SELECT2.md',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/vendor/select2/select2.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/vendor/select2/select2.min.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/css/widgets.css',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/README.md',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/calendar-icons.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-addlink.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-alert-dark.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-alert.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-calendar.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-changelink.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-clock.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-debug-dark.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-debug.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-deletelink.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-hidelink.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-info-dark.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-info.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-no-dark.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-no.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-unknown-alt.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-unknown.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-viewlink.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-yes-dark.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/icon-yes.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/inline-delete.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/search.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/selector-icons.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/sorting-icons.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/tooltag-add.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/img/tooltag-arrowright.svg',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/SelectBox.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/SelectFilter2.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/actions.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/admin/DateTimeShortcuts.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/admin/RelatedObjectLookups.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/autocomplete.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/calendar.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/cancel.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/change_form.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/core.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/filters.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/inlines.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/jquery.init.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/nav_sidebar.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/popup_response.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/prepopulate.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/prepopulate_init.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/theme.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/urlify.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/jquery/LICENSE.txt',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/jquery/jquery.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/jquery/jquery.min.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/LICENSE.md',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/af.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ar.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/az.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/bg.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/bn.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/bs.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ca.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/cs.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/da.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/de.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/dsb.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/el.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/en.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/es.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/et.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/eu.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/fa.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/fi.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/fr.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/gl.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/he.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/hi.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/hr.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/hsb.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/hu.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/hy.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/id.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/is.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/it.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ja.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ka.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/km.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ko.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/lt.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/lv.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/mk.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ms.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/nb.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ne.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/nl.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/pl.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ps.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/pt-BR.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/pt.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ro.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/ru.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/sk.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/sl.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/sq.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/sr-Cyrl.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/sr.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/sv.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/th.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/tk.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/tr.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/uk.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/vi.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/zh-CN.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/i18n/zh-TW.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/select2.full.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/select2/select2.full.min.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/xregexp/LICENSE.txt',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/xregexp/xregexp.js',
#  '.venv/lib/python3.12/site-packages/django/contrib/admin/static/admin/js/vendor/xregexp/xregexp.min.js',
#  ...]

# %%
agent_tools.list_files("django_template")
# Out:
# []

# %%
agent_tools.list_files("myproject")
# Out:
# ['myproject/__init__.py',
#  'myproject/__pycache__/__init__.cpython-312.pyc',
#  'myproject/__pycache__/settings.cpython-312.pyc',
#  'myproject/__pycache__/urls.cpython-312.pyc',
#  'myproject/asgi.py',
#  'myproject/settings.py',
#  'myproject/urls.py',
#  'myproject/wsgi.py']

# %%
settings_text = agent_tools.read_file("myproject/settings.py")
print(settings_text[:1500])
# Out:
# """
# Django settings for myproject project.
#
# Generated by 'django-admin startproject' using Django 6.0.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/6.0/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/6.0/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/6.0/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = "django-insecure-wuk=tb3=o-m&gs+@u!rsxugd@nk-w#kfk9^a!^p0+zyo4m_kxc"
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
#
# # Application definition
#
# INSTALLED_APPS = [
#     "django.contrib.admin",
#     "django.contrib.auth",
#     "django.contrib.contenttypes",
#     "django.contrib.sessions",
#     "django.contrib.messages",
#     "django.contrib.staticfiles",
#     "myapp",
# ]
#
# MIDDLEWARE = [
#     "django.middleware.security.SecurityMiddleware",
#     "django.contrib.sessions.middleware.SessionMiddleware",
#     "django.middleware.common.CommonMiddleware",
#     "django.middleware.csrf.CsrfViewMiddleware",
#     "django.contrib.auth.middleware.AuthenticationMiddleware",
#     "django.contrib.messages.middleware.MessageMiddleware",
#     "django.middleware.clickjacking.XFrameOptionsMiddleware",
# ]
#
# R

# %% [markdown]
# ### Build the prompt explicitly for LLM

# %%
prompt = f"""
You are analyzing a Django project's settings.py file.

Summarize the following in bullet points:
- Django version and environment
- Installed apps
- Database configuration
- Middleware highlights
- Security-related settings
- Deployment readiness (DEBUG, ALLOWED_HOSTS, static/media)

Here is the file content:

{settings_text}
"""

# %% [markdown]
# #### Call the runner

# %%
response = runner.loop(prompt=prompt)
print(response.new_messages[-1].content)
# Out:
# [ResponseOutputText(annotations=[], text="Here's a summary of the provided Django project's settings:\n\n- **Django Version and Environment**\n  - Django version: 6.0\n  - Environment: Development (DEBUG is set to True)\n\n- **Installed Apps**\n  - Built-in apps:\n    - `django.contrib.admin`\n    - `django.contrib.auth`\n    - `django.contrib.contenttypes`\n    - `django.contrib.sessions`\n    - `django.contrib.messages`\n    - `django.contrib.staticfiles`\n  - Custom app:\n    - `myapp`\n\n- **Database Configuration**\n  - Database engine: SQLite (`django.db.backends.sqlite3`)\n  - Database name: `db.sqlite3` located in the base directory\n\n- **Middleware Highlights**\n  - Security Middleware: `django.middleware.security.SecurityMiddleware`\n  - Session Middleware: `django.contrib.sessions.middleware.SessionMiddleware`\n  - CSRF Protection: `django.middleware.csrf.CsrfViewMiddleware`\n  - Authentication Middleware: `django.contrib.auth.middleware.AuthenticationMiddleware`\n  - Clickjacking Protection: `django.middleware.clickjacking.XFrameOptionsMiddleware`\n\n- **Security-Related Settings**\n  - Secret key: Defined (note: keep it secret in production)\n  - Debug mode: Enabled (not recommended for production)\n  \n- **Deployment Readiness**\n  - DEBUG: True (not ready for production)\n  - ALLOWED_HOSTS: Empty list (no hosts allowed)\n  - Static files URL: `static/` (need to configure for production)", type='output_text', logprobs=[])]
